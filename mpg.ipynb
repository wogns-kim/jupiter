# %%
import pandas as pd
mpg = pd.read_csv('mpg.csv')
mpg('hwy')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 3
#       1 import pandas as pd
#       2 mpg = pd.read_csv('mpg.csv')
# ----> 3 mpg('hwy')
#
# TypeError: 'DataFrame' object is not callable

# %%
import pandas as pd
mpg = pd.read_csv('mpg.csv')
# Use square brackets to access a column in a DataFrame
mpg['hwy']  # Correct way to access the 'hwy' column

# Alternatively, you can use dot notation (though square brackets are preferred)
# mpg.hwy
# Out:
# 0      29
# 1      29
# 2      31
# 3      30
# 4      26
#        ..
# 229    28
# 230    29
# 231    26
# 232    26
# 233    26
# Name: hwy, Length: 234, dtype: int64

# %%
import pandas as pd
df = pd.DataFrame({'var' : [1,2,3],
                  'var' : [4,5,6]},
                 index = ['kim', 'lee','park'])
df
# Out:
#       var
# kim     4
# lee     5
# park    6

# %%
pd.DataFrame
# Out:
# pandas.core.frame.DataFrame

# %%
## 만들기
x = 1
x = 1.5 
x = 'apple'

type(x)
# Out:
# str

# %%
var2 = float(var2)
var3 = str(var3)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 var2 = float(var2)
#       2 var3 = str(var3)
#
# NameError: name 'var2' is not defined

# %%
import pandas as pd
df = pd.DataFrame({'name' : ['김지훈', ' 이유진' ,'박동현','김민지'],
                  'english' : [90,80,60,70],
                  'math' : [50,60,100,20]})
df
# Out:
#    name  english  math
# 0   김지훈       90    50
# 1   이유진       80    60
# 2   박동현       60   100
# 3   김민지       70    20

# %%
import pandas as pd
df = pd.DataFrame({'과일' : ['사과', '딸기','수박'],
                  '가격' : [1800,1500,3000],
                  '판매량' : [24, 38, 13]})
df
# Out:
#    과일    가격  판매량
# 0  사과  1800   24
# 1  딸기  1500   38
# 2  수박  3000   13

# %%
sum(df['가격'])/3
# Out:
# 2100.0

# %%
df_exam = pd.read_excel('excel+exam.xlsx')
df_exam
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 df_exam = pd.read_excel('excel+exam.xlsx')
#       2 df_exam
#
# File /opt/anaconda3/lib/python3.13/site-packages/pandas/io/excel/_base.py:495, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     493 if not isinstance(io, ExcelFile):
#     494     should_close = True
# --> 495     io = ExcelFile(
#     496         io,
#     497         storage_options=storage_options,
#     498         engine=engine,
#     499         engine_kwargs=engine_kwargs,
#     500     )
#     501 elif engine and engine != io.engine:
#     502     raise ValueError(
# ...
